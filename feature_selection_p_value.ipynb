# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
wi=pd.read_csv("wine_outli.csv")

# %%
wi.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %%
inp_df=wi.drop("quality",axis=1)

# %%
inp_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
df1=ss.fit_transform(inp_df)

# %%
df2=pd.DataFrame(df1,columns=inp_df.columns)

# %%
df2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.506257          1.084072    -1.395226       -0.660402  -0.193503
# 1         -0.237876          2.171450    -1.395226        0.980050   1.341692
# 2         -0.237876          1.446531    -1.188918        0.276999   0.923002
# 3          2.043366         -1.453143     1.493090       -0.660402  -0.263285
# 4         -0.506257          1.084072    -1.395226       -0.660402  -0.193503
# ...             ...               ...          ...             ...        ...
# 1594      -1.311401          0.479973    -0.982609       -0.426051   0.783439
# 1595      -1.512687          0.177924    -0.879455        0.042649  -1.170445
# 1596      -1.244306         -0.063716    -0.724724        0.276999  -0.193503
# 1597      -1.512687          0.751818    -0.776301       -0.426051  -0.263285
# 1598      -1.445592         -1.271913     1.028897        3.323553  -0.821537
#
# ...

# %%
import statsmodels.api as sm

# %%
y=wi['quality']

# %%
df2=sm.add_constant(df2)
mo=sm.OLS(y,df2)

# %%
res=mo.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     74.08
# Date:                Sun, 17 Nov 2024   Prob (F-statistic):          2.59e-134
# Time:                        09:34:17   Log-Likelihood:                -1456.2
# No. Observations:                1599   AIC:                             2936.
# Df Residuals:                    1587   BIC:                             3001.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
fin_df=df2.drop("residual sugar",axis=1)

# %%
df2.head()
# Out:
#    const  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    1.0      -0.506257          1.084072    -1.395226       -0.660402
# 1    1.0      -0.237876          2.171450    -1.395226        0.980050
# 2    1.0      -0.237876          1.446531    -1.188918        0.276999
# 3    1.0       2.043366         -1.453143     1.493090       -0.660402
# 4    1.0      -0.506257          1.084072    -1.395226       -0.660402
#
#    chlorides  free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0  -0.193503            -0.455657             -0.329932  0.648369  1.448448
# 1   1.341692             1.076386              0.903736  0.039563 -0.783248
# 2   0.923002            -0.017931              0.417746  0.161324 -0.351307
# 3  -0.263285             0.200933              0.642049  0.770130 -1.071209
# 4  -0.193503            -0.455657             -0.329932  0.648369  1.448448
#
#    sulphates   alcohol
# 0  -0.638601 -0.976125
# 1   0.372245 -0.582843
# ...

# %%
fin_df['quality']=wi['quality']

# %%
fin_df.head()
# Out:
#    const  fixed acidity  volatile acidity  citric acid  chlorides  \
# 0    1.0      -0.506257          1.084072    -1.395226  -0.193503
# 1    1.0      -0.237876          2.171450    -1.395226   1.341692
# 2    1.0      -0.237876          1.446531    -1.188918   0.923002
# 3    1.0       2.043366         -1.453143     1.493090  -0.263285
# 4    1.0      -0.506257          1.084072    -1.395226  -0.193503
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.455657             -0.329932  0.648369  1.448448  -0.638601
# 1             1.076386              0.903736  0.039563 -0.783248   0.372245
# 2            -0.017931              0.417746  0.161324 -0.351307   0.119534
# 3             0.200933              0.642049  0.770130 -1.071209  -0.470127
# 4            -0.455657             -0.329932  0.648369  1.448448  -0.638601
#
#     alcohol  quality
# 0 -0.976125      5.0
# 1 -0.582843      5.0
# 2 -0.582843      5.0
# ...

# %%
fin_df.to_csv("model_ready.csv",index=False)
